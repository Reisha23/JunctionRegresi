# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('traffic.csv')
data.head()
# Out:
#               DateTime  Junction  Vehicles           ID
# 0  2015-11-01 00:00:00         1        15  20151101001
# 1  2015-11-01 01:00:00         1        13  20151101011
# 2  2015-11-01 02:00:00         1        10  20151101021
# 3  2015-11-01 03:00:00         1         7  20151101031
# 4  2015-11-01 04:00:00         1         9  20151101041

# %%
data.shape
# Out:
# (48120, 4)

# %%
print(data.isnull())
# Out:
#        DateTime  Junction  Vehicles     ID
# 0         False     False     False  False
# 1         False     False     False  False
# 2         False     False     False  False
# 3         False     False     False  False
# 4         False     False     False  False
# ...         ...       ...       ...    ...
# 48115     False     False     False  False
# 48116     False     False     False  False
# 48117     False     False     False  False
# 48118     False     False     False  False
# 48119     False     False     False  False
#
# [48120 rows x 4 columns]

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48120 entries, 0 to 48119
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  48120 non-null  object
#  1   Junction  48120 non-null  int64
#  2   Vehicles  48120 non-null  int64
#  3   ID        48120 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
# None

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48120 entries, 0 to 48119
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  48120 non-null  object
#  1   Junction  48120 non-null  int64
#  2   Vehicles  48120 non-null  int64
#  3   ID        48120 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
data.nunique()
# Out:
# DateTime    14592
# Junction        4
# Vehicles      141
# ID          48120
# dtype: int64

# %%
data.describe()
# Out:
#            Junction      Vehicles            ID
# count  48120.000000  48120.000000  4.812000e+04
# mean       2.180549     22.791334  2.016330e+10
# std        0.966955     20.750063  5.944854e+06
# min        1.000000      1.000000  2.015110e+10
# 25%        1.000000      9.000000  2.016042e+10
# 50%        2.000000     15.000000  2.016093e+10
# 75%        3.000000     29.000000  2.017023e+10
# max        4.000000    180.000000  2.017063e+10

# %%
data.describe(include='object')
# Out:
#                    DateTime
# count                 48120
# unique                14592
# top     2017-06-30 23:00:00
# freq                      4

# %%
data['DateTime']=pd.to_datetime(data['DateTime'])
data["year"]=data['DateTime'].dt.year
data["Month"]=data['DateTime'].dt.month
data["Dat"]=data['DateTime'].dt.day
data["Hour"]=data['DateTime'].dt.hour
data["Day"]= data['DateTime'].dt.strftime("%A")
data
# Out:
#                  DateTime  Junction  Vehicles           ID  year  Month  Dat  \
# 0     2015-11-01 00:00:00         1        15  20151101001  2015     11    1
# 1     2015-11-01 01:00:00         1        13  20151101011  2015     11    1
# 2     2015-11-01 02:00:00         1        10  20151101021  2015     11    1
# 3     2015-11-01 03:00:00         1         7  20151101031  2015     11    1
# 4     2015-11-01 04:00:00         1         9  20151101041  2015     11    1
# ...                   ...       ...       ...          ...   ...    ...  ...
# 48115 2017-06-30 19:00:00         4        11  20170630194  2017      6   30
# 48116 2017-06-30 20:00:00         4        30  20170630204  2017      6   30
# 48117 2017-06-30 21:00:00         4        16  20170630214  2017      6   30
# 48118 2017-06-30 22:00:00         4        22  20170630224  2017      6   30
# 48119 2017-06-30 23:00:00         4        12  20170630234  2017      6   30
#
#        Hour     Day
# 0         0  Sunday
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
sns.lineplot(x=data['Dat'],y="Vehicles",data=data,hue='Junction')
# Out:
# <Axes: xlabel='Dat', ylabel='Vehicles'>

# %%
date_hr=data[['Day','year','Month','Dat','Hour']]

# %%
for i in date_hr:
    plt.figure(figsize=(15,6))
    sns.lineplot(x=date_hr[i], y='Vehicles', data=data,hue='Junction')
    plt.title(f'{i} vs vVehicles')
    plt.xlabel(i)
    plt.ylabel('Vechicles')
    plt.legend()
    plt.xticks(rotation=90)
    plt.show()

# %%
sns.countplot(x=data['Junction'],data=data)
# Out:
# <Axes: xlabel='Junction', ylabel='count'>

# %%
sns.scatterplot(x=data['Day'],y="Vehicles",data=data,hue='Junction')
# Out:
# <Axes: xlabel='Day', ylabel='Vehicles'>

# %%
data=data.copy()

# %%
data.head()
# Out:
#              DateTime  Junction  Vehicles           ID  year  Month  Dat  \
# 0 2015-11-01 00:00:00         1        15  20151101001  2015     11    1
# 1 2015-11-01 01:00:00         1        13  20151101011  2015     11    1
# 2 2015-11-01 02:00:00         1        10  20151101021  2015     11    1
# 3 2015-11-01 03:00:00         1         7  20151101031  2015     11    1
# 4 2015-11-01 04:00:00         1         9  20151101041  2015     11    1
#
#    Hour     Day
# 0     0  Sunday
# 1     1  Sunday
# 2     2  Sunday
# 3     3  Sunday
# 4     4  Sunday
